# %% [markdown]
# #REST-API
# [참고](https://velog.io/@somday/RESTful-API-%EC%9D%B4%EB%9E%80)

# %% [markdown]
# 영화진흥위원회

# %%
import getpass

api_key = getpass.getpass('API키를 입력하세요 : ')
daily_box_office = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json'
# Out:
# API키를 입력하세요 : ··········

# %%
import requests
params = {'key' : api_key, 'targetDt' : '20220730'}
response = requests.get(daily_box_office, params)

# %%
import json
box_office_0730 = json.loads(response.text)

# %%
box_office_0730 = box_office_0730['boxOfficeResult']['dailyBoxOfficeList']

# %%
import pandas as pd
from pandas import json_normalize

# %%
json_normalize(box_office_0730)
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd            movieNm      openDt  \
# 0    1    1         0           OLD  20209343          한산: 용의 출현  2022-07-27
# 1    2    2         0           OLD  20205362              미니언즈2  2022-07-20
# 2    3    3         0           OLD  20194376            탑건: 매버릭  2022-06-22
# 3    4    4         0           OLD  20208446            외계+인 1부  2022-07-20
# 4    5    5         0           OLD  20225190  뽀로로 극장판 드래곤캐슬 대모험  2022-07-28
# 5    6    6         0           OLD  20209654             헤어질 결심  2022-06-29
# 6    7    7         0           OLD  20225237    명탐정 코난: 할로윈의 신부  2022-07-13
# 7    8    8         0           OLD  20224662        토르: 러브 앤 썬더  2022-07-06
# 8    9    9         0           NEW  20196410               비상선언  2022-08-03
# 9   10   10         1           OLD  20225175                엘비스  2022-07-13
#
#      salesAmt salesShare  salesInten salesChange     salesAcc audiCnt  \
# 0  7130335397       61.6  3752057145       111.1  16351564571  660932
# 1  1273037950       11.0   379626388        42.5  13449490718  125938
# 2  1305695304       11.3   596635846        84.1  74028021941  119020
# 3   796481323        6.9   317736552        66.4  13450034147   73678
# 4   456941728        3.9   123061229        36.9   1173230377   46925
# 5   338627537        2.9   111405860          49  16979553720   30453
# 6   115269216        1.0    17289097        17.6   4166206988   10585
# 7    29228469        0.3    11372870        63.7  29413748364    2549
# 8    25303600        0.2    25303600         100    118941600    2077
# 9    15419780        0.1     5945780        62.8    902901130    1388
#
#   audiInten audiChange  audiAcc scrnCnt showCnt
# 0    345440      109.5  1614467    2139   10340
# 1     34634       37.9  1381810    1064    3039
# 2     53692       82.2  6937072     867    2045
# 3     28711       63.8  1288794     759    1851
# 4     12070       34.6   123907     748    1607
# 5      9907       48.2  1644791     421     742
# 6      1523       16.8   401287     211     300
# 7       926       57.1  2707598      53      69
# 8      2077        100    13567       8       9
# 9       497       55.8    84112      28      34

# %% [markdown]
# 저번주의 주중 한국영화의 박스오피스

# %%
weekly_box_office = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json'

# %%
params = {"key":api_key, 'targetDt':'20220725', 'weekGb':'2', 'repNationCd':'K'}
response = requests.get(weekly_box_office, params)

# %%
box_office_weekly = json.loads(response.text)

# %%
box_office_weekly = box_office_weekly["boxOfficeResult"]["weeklyBoxOfficeList"]

# %%
json_normalize(box_office_weekly)
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd                         movieNm  \
# 0    1    1         5           OLD  20209343                       한산: 용의 출현
# 1    2    2        -1           OLD  20208446                         외계+인 1부
# 2    3    3        -1           OLD  20209654                          헤어질 결심
# 3    4    4        15           OLD  20225190               뽀로로 극장판 드래곤캐슬 대모험
# 4    5    5         0           NEW  20196410                            비상선언
# 5    6    6        -3           OLD  20204548                          범죄도시 2
# 6    7    7        -3           OLD  20225186                 더 킬러: 죽어도 되는 아이
# 7    8    8         0           NEW  20226207  비욘드 라이브 더 무비: 엑소의 사다리 타고 세계여행3
# 8    9    9         0           NEW  20211792                              헌트
# 9   10   10         1           OLD  20223985                       아이를 위한 아이
#
#        openDt    salesAmt salesShare  salesInten salesChange      salesAcc  \
# 0  2022-07-27  5767104422       58.8  5734535422     17607.3    5842950922
# 1  2022-07-20  2491284972       25.4  -348454006       -12.3   12174808053
# 2  2022-06-29   913814965        9.3  -319224829       -25.9   16413704506
# 3  2022-07-28   376599150        3.8   374376150     16841.0     382408150
# 4  2022-08-03    93638000        1.0    93638000       100.0      93638000
# 5  2022-05-18    42994420        0.4  -121783240       -73.9  131250086960
# 6  2022-07-13    23284260        0.2   -71964200       -75.6     599921660
# 7  2022-07-27    33509500        0.3    33509500       100.0      33509500
# 8  2022-08-10    18964000        0.2    18964000       100.0      18964000
# 9  2022-07-21     9543200        0.1     2442900        34.4      33233300
#
#   audiCnt audiInten audiChange   audiAcc scrnCnt showCnt
# 0  631355    628066    19096.0    638043    2223   20856
# 1  256882    -21691       -7.8   1170149    1525   16248
# 2   92442    -26586      -22.3   1593792     672    4035
# 3   41500     41253    16701.6     42127     695    1357
# 4   11490     11490      100.0     11490      27      54
# 5    4419    -11920      -73.0  12688986     121     437
# 6    3878     -5548      -58.9     60013      55     159
# 7    2031      2031      100.0      2031      18      25
# 8    1752      1752      100.0      1752       5       6
# 9    1122       272       32.0      3839      43     172

# %% [markdown]
# 네이버 API를 이용해 이미지 검색하기

# %%
import os
import sys
import urllib.request
client_id = getpass.getpass("YOUR_CLIENT_ID : ") # 개발자센터에서 발급받은 Client ID 값
client_secret = getpass.getpass("YOUR_CLIENT_SECRET") # 개발자센터에서 발급받은 Client Secret 값
# Out:
# YOUR_CLIENT_ID : ··········
# YOUR_CLIENT_SECRET··········

# %%
encText = urllib.parse.quote(input("한글을 입력하세요 : "))
data = "source=ko&target=en&text=" + encText
url = "https://openapi.naver.com/v1/papago/n2mt"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    result = response_body.decode('utf-8')
    result_dict = json.loads(result)
    print("결과 : ",result_dict["message"]["result"]["translatedText"])
else:
    print("Error Code:" + rescode)
# Out:
# 한글을 입력하세요 : 만나서 반갑습니다
# 결과 :  Good to meet you.

# %%
result = response_body.decode('utf-8')
result_dict = json.loads(result)

# %%
result_dict["message"]["result"]["translatedText"]
# Out:
# 'Good to meet you.'
