# %% [markdown]
# # Ex2 - Filtering and Sorting Data
# Check out [Euro 12 Exercises Video Tutorial](https://youtu.be/iqk5d48Qisg) to watch a data scientist go through the exercises

# %% [markdown]
# This time we are going to pull data directly from the internet.
#
# ### Step 1. 필요한 라이브러리 들을 import 하세요

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. 다음 주소의 파일을 import 하세요 [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv).

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv"

# %% [markdown]
# ### Step 3.euro12 라는 변수에 DataFrame을 할당하세요

# %%
euro12  = pd.read_csv(url , sep = ",")

# %% [markdown]
# ### Step 4. Goal column을 출력하세요

# %%
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# ### Step 5. Euro2012에는 몇팀이 참가 했습니까?

# %%
len(euro12)
# Out:
# 16

# %% [markdown]
# ### Step 6. Dataset의 컬럼은 몇개 인가요?

# %%
len(euro12.columns)
# Out:
# 35

# %% [markdown]
# ### Step 7. discipline 변수에 각 Team 당 Yellow Cards, Red Cards 을 dataframe으로 할당하여라

# %%
discipline = pd.DataFrame(euro12[['Team', 'Yellow Cards', 'Red Cards']])

# %% [markdown]
# ### Step 8. Red Cards로 정렬한 다음 Yellow Cards로 정렬하시오

# %%
discipline.sort_values(['Red Cards', 'Yellow Cards'])
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %% [markdown]
# ### Step 9. 팀당 평균 Yellow Cards 의 비율은 얼마인가?

# %%
euro12['Yellow Cards'].mean()
# Out:
# 7.4375

# %% [markdown]
# ### Step 10. 6골이상 득점한 팀을 필터링 하시오

# %%
euro12[euro12.Goals >= 6]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5    Germany     10               32                32             47.8%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 13     Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 7              7.5%                         110             2              0
# 10             9.3%                          82             6              0
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# ...

# %% [markdown]
# ### Step 11."G" 로 시작하는 팀을 선택하시오

# %%
euro12[euro12['Team'].str.startswith('G')]
euro12[euro12.Team.str[0] == 'G'][['Team', 'Shooting Accuracy']]
# Out:
#       Team Shooting Accuracy
# 5  Germany             47.8%
# 6   Greece             30.7%

# %% [markdown]
# ### Step 12. DataFrame의 처음부터 7번째 column 까지 출력하시오

# %%
euro12.iloc[:,0:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 13. 마지막 3개를 제외한 모든 columns 을 선택하시오

# %%
euro12.iloc[:,0:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 14. England, Italy, Russia의 슈팅 정확도를 출력하시오

# %%
# 1
teams = ['England', 'Italy', 'Russia']
list2 = '|'.join(list1)
euro12[euro12['Team'].str.contains(list2)][['Team', 'Shooting Accuracy']]

# 2
euro12[euro12['Team'].isin(teams)][['Team', 'Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%
